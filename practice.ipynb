# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Plotting the graph
plt.plot(x, y)

# Adding title and labels
plt.title("Basic Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("data.csv")

# Print the data
print("Marks Data:\n", df)

# Plot bar chart
plt.bar(df["Name"], df["Marks"], color="skyblue")

# Add labels and title
plt.title("Students Marks")
plt.xlabel("Name")
plt.ylabel("Marks")

# Show the chart
plt.show()
# Out:
# Marks Data:
#        Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78
# 3    David     92
# 4     Emma     88

# %%
import pandas as pd

# Read CSV file
ama = pd.read_csv("amazon_products.csv")

print("Product data:\n",ama)
# Out:
# Product data:
#     ProductID    ProductName    Brand     Category    Price  Rating  Stock  \
# 0       P001  Tennis Racket    Apple       Sports   318.86     3.0     53
# 1       P002          Shoes       HP         Home   605.31     2.1    322
# 2       P003      Microwave     Dell       Beauty   888.40     1.4    173
# 3       P004           Doll       HP       Beauty  1395.83     2.6     80
# 4       P005     Smartwatch  Samsung         Home    28.09     1.2     21
# ..       ...            ...      ...          ...      ...     ...    ...
# 95      P096           Book   Adidas         Home   382.82     4.7    266
# 96      P097     Smartphone  Philips        Books  1473.29     4.4    353
# 97      P098       Lipstick       HP        Books  1580.08     1.7    138
# 98      P099        Toy Car   Adidas  Electronics    31.30     1.7    338
# 99      P100  Tennis Racket  Samsung       Beauty    53.59     2.7     54
#
#     Discount(%)
# 0            15
# 1             0
# 2            25
# 3            20
# 4            10
# ..          ...
# 95           30
# 96           15
# 97           15
# 98           15
# 99           25
#
# [100 rows x 8 columns]

# %%
print(ama.head())
print("\n",ama.head(4))
# Out:
#   ProductID    ProductName    Brand Category    Price  Rating  Stock  \
# 0      P001  Tennis Racket    Apple   Sports   318.86     3.0     53
# 1      P002          Shoes       HP     Home   605.31     2.1    322
# 2      P003      Microwave     Dell   Beauty   888.40     1.4    173
# 3      P004           Doll       HP   Beauty  1395.83     2.6     80
# 4      P005     Smartwatch  Samsung     Home    28.09     1.2     21
#
#    Discount(%)
# 0           15
# 1            0
# 2           25
# 3           20
# 4           10
#
#    ProductID    ProductName  Brand Category    Price  Rating  Stock  \
# 0      P001  Tennis Racket  Apple   Sports   318.86     3.0     53
# 1      P002          Shoes     HP     Home   605.31     2.1    322
# 2      P003      Microwave   Dell   Beauty   888.40     1.4    173
# 3      P004           Doll     HP   Beauty  1395.83     2.6     80
#
#    Discount(%)
# 0           15
# 1            0
# 2           25
# 3           20

# %%
print(ama.tail())
print("\n",ama.tail(3))
# Out:
#    ProductID    ProductName    Brand     Category    Price  Rating  Stock  \
# 95      P096           Book   Adidas         Home   382.82     4.7    266
# 96      P097     Smartphone  Philips        Books  1473.29     4.4    353
# 97      P098       Lipstick       HP        Books  1580.08     1.7    138
# 98      P099        Toy Car   Adidas  Electronics    31.30     1.7    338
# 99      P100  Tennis Racket  Samsung       Beauty    53.59     2.7     54
#
#     Discount(%)
# 95           30
# 96           15
# 97           15
# 98           15
# 99           25
#
#     ProductID    ProductName    Brand     Category    Price  Rating  Stock  \
# 97      P098       Lipstick       HP        Books  1580.08     1.7    138
# 98      P099        Toy Car   Adidas  Electronics    31.30     1.7    338
# 99      P100  Tennis Racket  Samsung       Beauty    53.59     2.7     54
#
#     Discount(%)
# 97           15
# 98           15
# 99           25

# %%
print(ama.isnull().sum())
# Out:
# ProductID      0
# ProductName    0
# Brand          0
# Category       0
# Price          0
# Rating         0
# Stock          0
# Discount(%)    0
# dtype: int64

# %%
print(ama.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    100 non-null    object
#  1   ProductName  100 non-null    object
#  2   Brand        100 non-null    object
#  3   Category     100 non-null    object
#  4   Price        100 non-null    float64
#  5   Rating       100 non-null    float64
#  6   Stock        100 non-null    int64
#  7   Discount(%)  100 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 6.4+ KB
# None

# %%
print(ama.columns)
# Out:
# Index(['ProductID', 'ProductName', 'Brand', 'Category', 'Price', 'Rating',
#        'Stock', 'Discount(%)'],
#       dtype='object')

# %%
print(ama.shape)
# Out:
# (100, 8)

# %%
#we can remove null values by using ".dropna()".
#to remove rows where a specific column has nulls ".dropna(subset=["colum_name"])"
#remove columns with null values "dropna(axis=1)" drops entire column if they contain null values.

# %%
import numpy as np

# Create numpy arrays
arr1 = np.array([1, 2, 3, 4, 5])
arr2 = np.array([10, 20, 30, 40, 50])

print("Addition:", arr1 + arr2)
print("Subtraction:", arr2 - arr1)
print("Multiplication:", arr1 * arr2)
print("Division:", arr2 / arr1)


print("Mean of arr1:", np.mean(arr1))
print("Max of arr2:", np.max(arr2))
print("Square root of arr1:", np.sqrt(arr1))
print("Reshape arr2 (1 row, 5 cols):", arr2.reshape(1, 5))
# Out:
# Addition: [11 22 33 44 55]
# Subtraction: [ 9 18 27 36 45]
# Multiplication: [ 10  40  90 160 250]
# Division: [10. 10. 10. 10. 10.]
# Mean of arr1: 3.0
# Max of arr2: 50
# Square root of arr1: [1.         1.41421356 1.73205081 2.         2.23606798]
# Reshape arr2 (1 row, 5 cols): [[10 20 30 40 50]]

# %%
import numpy as np
#import matplotlib.pyplot as plt
from matplotlib.image import imread

# Read image as NumPy array
img = imread("screenshot.png")
print("image:",img.shape)
# Out:
# image: (768, 1366, 4)

# %%
import numpy as np

x = np.array([75, 82, 90, 65, 88])

avg = np.mean(x)
max = np.max(x)
print("Average:", avg)
print("Max:",max)
# Out:
# Average: 80.0
# Max: 90

# %%
import pandas as pd

emp = pd.read_csv("employees.csv")

print("First 5 employees:\n", emp.head())

print("\nEmployee Age and Gender:\n", emp[["Name", "Age", "Gender"]])

print("\nGender Count:\n", emp["Gender"].value_counts())

max_age=emp["Age"].max()
print("\nmax Age is:",max_age)
# Out:
# First 5 employees:
#    EmployeeID   Name  Age  Gender Department
# 0       E001  Queen   34  Female      Sales
# 1       E002   Emma   25  Female         IT
# 2       E003    Tom   56  Female      Admin
# 3       E004  Karen   37    Male    Finance
# 4       E005  Alice   58    Male    Finance
#
# Employee Age and Gender:
#         Name  Age  Gender
# 0     Queen   34  Female
# 1      Emma   25  Female
# 2       Tom   56  Female
# 3     Karen   37    Male
# 4     Alice   58    Male
# 5      Mona   41    Male
# 6      Emma   55  Female
# 7     Grace   28    Male
# 8     Henry   32    Male
# 9     Grace   53    Male
# 10      Tom   52    Male
# 11    David   32  Female
# 12    Queen   40    Male
# 13  Charlie   30    Male
# 14    Grace   43    Male
# 15     Mona   60    Male
# 16   Sophia   44    Male
# 17    Henry   29  Female
# 18    Queen   42  Female
# 19    Oscar   47    Male
# 20   Robert   29  Female
# 21    Grace   50    Male
# 22    Alice   36    Male
# 23    Grace   26    Male
# 24   Sophia   41    Male
# 25   Sophia   27    Male
# 26    Alice   39  Female
# 27      Ivy   56  Female
# 28    Grace   34    Male
# 29   Sophia   24  Female
# 30    Henry   27  Female
# 31      Bob   28    Male
# 32   Robert   36  Female
# 33     Jack   35    Male
# 34     Mona   26  Female
# 35    Henry   22    Male
# 36    David   50  Female
# 37      Tom   40    Male
# 38    Frank   45  Female
# 39     Nina   51  Female
# 40      Bob   28  Female
# 41     Mona   27  Female
# 42     Nina   53  Female
# 43     Paul   58    Male
# 44     Emma   43    Male
# 45    Alice   31    Male
# 46    Oscar   42  Female
# 47    Alice   30    Male
# 48    Alice   42  Female
# 49    Alice   35  Female
#
# Gender Count:
#  Gender
# Male      27
# Female    23
# Name: count, dtype: int64
#
# max Age is: 60

# %%
emp_id = input("Enter EmployeeID to get details:")
employee = emp[emp["EmployeeID"] == emp_id]

print(employee)
# Out:
#    EmployeeID   Name  Age Gender Department
# 14       E015  Grace   43   Male         IT

# %%
import pandas as pd

marks = pd.read_csv("marks.csv")

print("First 5 rows:\n", marks.head())

print("\nAverage Marks:\n", marks[["Math","Science","English","History","Computer"]].mean())
# Out:
# First 5 rows:
#    StudentID  Gender  Math  Science  English  History  Computer  Total  \
# 0      S001  Female    85       78       92       74        88    417
# 1      S002    Male    65       70       68       72        66    341
# 2      S003    Male    55       60       58       62        57    292
# 3      S004    Male    90       85       88       92        94    449
# 4      S005  Female    72       76       74       78        70    370
#
#    Percentage Grade
# 0        83.4     A
# 1        68.2     B
# 2        58.4     C
# 3        89.8     A
# 4        74.0     B
#
# Average Marks:
#  Math        73.95
# Science     75.30
# English     75.35
# History     73.90
# Computer    74.35
# dtype: float64

# %%
stu_id = input("Enter StudendID to get details:")
student = marks[marks["StudentID"] == stu_id]

print(student)
# Out:
#   StudentID  Gender  Math  Science  English  History  Computer  Total  \
# 0      S001  Female    85       78       92       74        88    417
#
#    Percentage Grade
# 0        83.4     A

# %%
grade = input("Enter Grade to find students: ")
find_grade = marks[marks["Grade"] == grade]
print(f"\n Students with Grade {grade}:\n",find_grade)
# Out:
#  Students with Grade C:
#     StudentID Gender  Math  Science  English  History  Computer  Total  \
# 2       S003   Male    55       60       58       62        57    292
# 9       S010   Male    50       55       52       48        54    259
# 14      S015   Male    58       62       60       55        59    294
#
#     Percentage Grade
# 2         58.4     C
# 9         51.8     C
# 14        58.8     C

# %%
per = float(input("Enter a Value to find Percentage : "))

find_per = marks[marks["Percentage"] >= per]

print(f"Students with Percentage {per}% and above:\n", find_per)
# Out:
# Students with Percentage 83.0% and above:
#     StudentID  Gender  Math  Science  English  History  Computer  Total  \
# 0       S001  Female    85       78       92       74        88    417
# 3       S004    Male    90       85       88       92        94    449
# 6       S007  Female    95       92       90       94        96    467
# 10      S011  Female    88       82       86       90        84    430
# 13      S014  Female    92       95       94       90        93    464
# 15      S016    Male    84       88       86       82        85    425
# 18      S019  Female    91       89       94       90        92    456
#
#     Percentage Grade
# 0         83.4     A
# 3         89.8     A
# 6         93.4     A
# 10        86.0     A
# 13        92.8     A
# 15        85.0     A
# 18        91.2     A

# %%
import pandas as pd

amazon = pd.read_csv("amazon_products.csv")
print(amazon)
# Out:
#    ProductID    ProductName    Brand     Category    Price  Rating  Stock  \
# 0       P001  Tennis Racket    Apple       Sports   318.86     3.0   53.0
# 1       P002          Shoes       HP         Home   605.31     2.1  322.0
# 2       P003      Microwave     Dell       Beauty   888.40     1.4  173.0
# 3       P004           Doll       HP       Beauty  1395.83     2.6   80.0
# 4       P005     Smartwatch  Samsung         Home    28.09     1.2   21.0
# ..       ...            ...      ...          ...      ...     ...    ...
# 95      P096           Book   Adidas         Home   382.82     4.7  266.0
# 96      P097     Smartphone  Philips        Books  1473.29     4.4    NaN
# 97      P098       Lipstick       HP        Books  1580.08     1.7  138.0
# 98      P099        Toy Car   Adidas  Electronics    31.30     1.7  338.0
# 99      P100            NaN  Samsung       Beauty    53.59     2.7   54.0
#
#     Discount(%)
# 0          15.0
# 1           NaN
# 2          25.0
# 3          20.0
# 4          10.0
# ..          ...
# 95         30.0
# 96         15.0
# 97         15.0
# 98         15.0
# 99         25.0
#
# [100 rows x 8 columns]

# %%
print(amazon.isnull().sum())
# Out:
# ProductID      0
# ProductName    3
# Brand          1
# Category       1
# Price          3
# Rating         2
# Stock          1
# Discount(%)    1
# dtype: int64

# %%
null = amazon.dropna()
print("After removing null values:\n",null)
# Out:
# After removing null values:
#     ProductID    ProductName    Brand     Category    Price  Rating  Stock  \
# 0       P001  Tennis Racket    Apple       Sports   318.86     3.0   53.0
# 2       P003      Microwave     Dell       Beauty   888.40     1.4  173.0
# 3       P004           Doll       HP       Beauty  1395.83     2.6   80.0
# 4       P005     Smartwatch  Samsung         Home    28.09     1.2   21.0
# 5       P006       Football     Dell       Beauty  1090.46     1.7  301.0
# ..       ...            ...      ...          ...      ...     ...    ...
# 91      P092     Headphones       LG         Toys   273.12     2.3  326.0
# 93      P094       Lipstick       HP     Clothing   203.82     1.7  380.0
# 95      P096           Book   Adidas         Home   382.82     4.7  266.0
# 97      P098       Lipstick       HP        Books  1580.08     1.7  138.0
# 98      P099        Toy Car   Adidas  Electronics    31.30     1.7  338.0
#
#     Discount(%)
# 0          15.0
# 2          25.0
# 3          20.0
# 4          10.0
# 5          25.0
# ..          ...
# 91          5.0
# 93         10.0
# 95         30.0
# 97         15.0
# 98         15.0
#
# [88 rows x 8 columns]

# %%
new_data = {"ProductID": "P101", "ProductName": "Laptop", "Brand": "asus","Category":"Electronics","Price":25000,"Rating":3.5,"Stock":335,"Discount(%)":8.0,}
amazon = pd.concat([amazon, pd.DataFrame([new_data])], ignore_index=True)
print(amazon)
# Out:
#     ProductID    ProductName    Brand     Category     Price  Rating  Stock  \
# 0        P001  Tennis Racket    Apple       Sports    318.86     3.0   53.0
# 1        P002          Shoes       HP         Home    605.31     2.1  322.0
# 2        P003      Microwave     Dell       Beauty    888.40     1.4  173.0
# 3        P004           Doll       HP       Beauty   1395.83     2.6   80.0
# 4        P005     Smartwatch  Samsung         Home     28.09     1.2   21.0
# ..        ...            ...      ...          ...       ...     ...    ...
# 96       P097     Smartphone  Philips        Books   1473.29     4.4    NaN
# 97       P098       Lipstick       HP        Books   1580.08     1.7  138.0
# 98       P099        Toy Car   Adidas  Electronics     31.30     1.7  338.0
# 99       P100            NaN  Samsung       Beauty     53.59     2.7   54.0
# 100      P101         Laptop     asus  Electronics  25000.00     3.5  335.0
#
#      Discount(%)
# 0           15.0
# 1            NaN
# 2           25.0
# 3           20.0
# 4           10.0
# ..           ...
# 96          15.0
# 97          15.0
# 98          15.0
# 99          25.0
# 100          8.0
#
# [101 rows x 8 columns]

# %%
#Task-sir will share in the gsroup
